# %%
curl -v https://kf.kobotoolbox.org/api/v2/assets/ak3QkwKnpveHvN9VpSnHVR/export/ -u datamike:doitbig2017
# Out:
#   Cell In[1], line 1
#     curl -v https://kf.kobotoolbox.org/api/v2/assets/ak3QkwKnpveHvN9VpSnHVR/export/ -u datamike:doitbig2017
#             ^
# SyntaxError: invalid syntax
